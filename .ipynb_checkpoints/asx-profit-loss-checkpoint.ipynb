# %%
# Import dependencies and setup
import matplotlib.pyplot as plt
import matplotlib as matplotlib
import pandas as pd
import glob

# %%
# 4DS
fourds_file_path = "Resources/4DS.csv"
fourds_df = pd.read_csv(fourds_file_path)
fourds_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
fourds_df
# Out:
#         Date   Open   High    Low  Close  Adj Close   Volume
# 0     1/5/20  0.043  0.045  0.043  0.044      0.044   830885
# 1     4/5/20  0.045  0.051  0.045  0.050      0.050  2202665
# 2     5/5/20  0.052  0.052  0.048  0.048      0.048  1109785
# 3     6/5/20  0.049  0.052  0.049  0.051      0.051  1468070
# 4     7/5/20  0.052  0.053  0.051  0.051      0.051  1252016
# ..       ...    ...    ...    ...    ...        ...      ...
# 457  17/2/22  0.077  0.077  0.072  0.073      0.073  7551171
# 458  18/2/22  0.072  0.072  0.069  0.070      0.070  9919401
# 459  21/2/22  0.071  0.073  0.065  0.066      0.066  8155230
# 460  22/2/22  0.065  0.067  0.062  0.064      0.064  8017361
# 461  23/2/22  0.062  0.066  0.060  0.064      0.064  7882934
#
# [462 rows x 7 columns]

# %%
# AFTP
aftp_file_path = "Resources/AFTP.csv"
aftp_df = pd.read_csv(aftp_file_path)
aftp_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
aftp_df
# Out:
#         Date       Open       High        Low      Close  Adj Close  Volume
# 0     1/5/20  21.000000  21.000000  21.000000  21.000000  21.000000     500
# 1     4/5/20  24.270000  24.270000  23.280001  23.280001  23.280001    1300
# 2     5/5/20  24.725000  24.780001  24.725000  24.780001  24.780001    1100
# 3     6/5/20  25.650000  25.650000  25.650000  25.650000  25.650000     400
# 4     7/5/20  25.370001  25.500000  25.370001  25.500000  25.500000     800
# ..       ...        ...        ...        ...        ...        ...     ...
# 452  15/2/22  41.700001  41.700001  39.680000  40.580002  40.580002  131400
# 453  16/2/22  40.290001  40.570000  40.279999  40.349998  40.349998   14700
# 454  17/2/22  40.689999  40.689999  40.110001  40.470001  40.470001   72500
# 455  18/2/22  40.360001  40.660000  40.360001  40.509998  40.509998   17500
# 456  22/2/22  39.849998  41.060001  39.849998  40.820000  40.820000  115800
#
# [457 rows x 7 columns]

# %%
# BRN
brn_file_path = "Resources/BRN.csv"
brn_df = pd.read_csv(brn_file_path)
brn_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
brn_df
# Out:
#         Date   Open    High     Low  Close  Adj Close    Volume
# 0     1/5/20  0.051  0.0530  0.0510  0.051      0.051   1646688
# 1     4/5/20  0.053  0.0535  0.0520  0.052      0.052   3356701
# 2     5/5/20  0.053  0.0530  0.0490  0.051      0.051   5016838
# 3     6/5/20  0.052  0.0520  0.0490  0.049      0.049   4981366
# 4     7/5/20  0.050  0.0510  0.0490  0.049      0.049   3648415
# ..       ...    ...     ...     ...    ...        ...       ...
# 457  17/2/22  1.460  1.4650  1.4075  1.420      1.420  10384080
# 458  18/2/22  1.380  1.4500  1.3550  1.405      1.405  16292378
# 459  21/2/22  1.390  1.3950  1.2700  1.295      1.295  24413919
# 460  22/2/22  1.250  1.2950  1.1650  1.195      1.195  37743853
# 461  23/2/22  1.170  1.2750  1.1650  1.250      1.250  21302007
#
# [462 rows x 7 columns]

# %%
# DW8
dw8_file_path = "Resources/DW8.csv"
dw8_df = pd.read_csv(dw8_file_path)
dw8_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
dw8_df
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0     1/5/20  0.006  0.006  0.006  0.006      0.006    515000
# 1     4/5/20  0.006  0.006  0.006  0.006      0.006         0
# 2     5/5/20  0.006  0.006  0.005  0.005      0.005  14450999
# 3     6/5/20  0.005  0.006  0.005  0.005      0.005   1532750
# 4     7/5/20  0.006  0.006  0.005  0.006      0.006   9976769
# ..       ...    ...    ...    ...    ...        ...       ...
# 457  17/2/22  0.039  0.041  0.039  0.040      0.040   3976783
# 458  18/2/22  0.039  0.041  0.039  0.039      0.039   6350267
# 459  21/2/22  0.039  0.039  0.038  0.039      0.039   3631123
# 460  22/2/22  0.040  0.040  0.037  0.038      0.038   3763997
# 461  23/2/22  0.036  0.038  0.036  0.038      0.038   3449501
#
# [462 rows x 7 columns]

# %%
# IMU
imu_file_path = "Resources/IMU.csv"
imu_df = pd.read_csv(imu_file_path)
imu_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
imu_df
# Out:
#         Date   Open   High    Low  Close  Adj Close    Volume
# 0     1/5/20  0.027  0.027  0.025  0.026      0.026  15968271
# 1     4/5/20  0.026  0.027  0.026  0.026      0.026   9260081
# 2     5/5/20  0.026  0.030  0.026  0.029      0.029  43605020
# 3     6/5/20  0.030  0.032  0.030  0.031      0.031  22998775
# 4     7/5/20  0.031  0.031  0.028  0.028      0.028  17827975
# ..       ...    ...    ...    ...    ...        ...       ...
# 457  17/2/22  0.310  0.315  0.300  0.310      0.310  38502826
# 458  18/2/22  0.295  0.310  0.295  0.300      0.300  15416970
# 459  21/2/22  0.300  0.300  0.280  0.280      0.280  20212704
# 460  22/2/22  0.280  0.280  0.250  0.255      0.255  58304658
# 461  23/2/22  0.250  0.270  0.245  0.260      0.260  35872403
#
# [462 rows x 7 columns]

# %%
# NVA
nva_file_path = "Resources/NVA.csv"
nva_df = pd.read_csv(nva_file_path)
nva_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
nva_df
# Out:
#         Date   Open   High   Low  Close  Adj Close  Volume
# 0     1/5/20  0.460  0.480  0.46  0.470      0.470  184555
# 1     4/5/20  0.470  0.490  0.47  0.480      0.480  124184
# 2     5/5/20  0.490  0.550  0.49  0.530      0.530  836320
# 3     6/5/20  0.540  0.540  0.53  0.530      0.530  355025
# 4     7/5/20  0.530  0.530  0.50  0.500      0.500  301664
# ..       ...    ...    ...   ...    ...        ...     ...
# 457  17/2/22  0.915  0.915  0.87  0.900      0.900  222456
# 458  18/2/22  0.915  0.945  0.90  0.930      0.930  149362
# 459  21/2/22  0.960  0.990  0.90  0.905      0.905  327561
# 460  22/2/22  0.910  0.915  0.85  0.870      0.870  321093
# 461  23/2/22  0.850  0.895  0.84  0.885      0.885   98785
#
# [462 rows x 7 columns]

# %%
# RAC
rac_file_path = "Resources/RAC.csv"
rac_df = pd.read_csv(rac_file_path)
rac_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
rac_df
# Out:
#         Date   Open   High    Low  Close  Adj Close  Volume
# 0     1/5/20  0.285  0.290  0.275  0.285      0.285  230183
# 1     4/5/20  0.280  0.300  0.275  0.300      0.300  338785
# 2     5/5/20  0.295  0.365  0.295  0.360      0.360  703900
# 3     6/5/20  0.355  0.390  0.345  0.345      0.345  288014
# 4     7/5/20  0.360  0.365  0.355  0.355      0.355   54006
# ..       ...    ...    ...    ...    ...        ...     ...
# 457  17/2/22  2.940  2.940  2.840  2.860      2.860  150065
# 458  18/2/22  2.810  2.850  2.800  2.820      2.820  160182
# 459  21/2/22  2.810  2.830  2.740  2.800      2.800  507481
# 460  22/2/22  2.800  2.800  2.730  2.800      2.800  372018
# 461  23/2/22  2.790  2.900  2.790  2.890      2.890  146053
#
# [462 rows x 7 columns]

# %%
# TNR
tnr_file_path = "Resources/TNR.csv"
tnr_df = pd.read_csv(tnr_file_path)
tnr_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
tnr_df
# Out:
#         Date      Open      High       Low     Close  Adj Close   Volume
# 0     1/5/20  0.019199  0.020159  0.015359  0.016319   0.016319  9475414
# 1     4/5/20  0.016319  0.017279  0.016319  0.017279   0.017279  2810436
# 2     5/5/20  0.017279  0.018239  0.017279  0.017279   0.017279  2124797
# 3     6/5/20  0.017279  0.018239  0.015359  0.015359   0.015359  3515663
# 4     7/5/20  0.016319  0.016319  0.015359  0.016319   0.016319   602926
# ..       ...       ...       ...       ...       ...        ...      ...
# 457  17/2/22  0.028000  0.029000  0.028000  0.028000   0.028000   838159
# 458  18/2/22  0.029000  0.029000  0.028500  0.029000   0.029000  2848130
# 459  21/2/22  0.029000  0.029000  0.027000  0.028000   0.028000  3016825
# 460  22/2/22  0.028000  0.028000  0.026000  0.026000   0.026000  5805127
# 461  23/2/22  0.026000  0.027000  0.026000  0.027000   0.027000  1875187
#
# [462 rows x 7 columns]

# %%
# Plot each ticker as seperate line graphs

# 4DS
# Define data
fourds_time = fourds_df['Date']
fourds_open = fourds_df['Open']
fourds_high = fourds_df['High']
fourds_low = fourds_df['Low']
fourds_close = fourds_df['Close']
fourds_adj_close = fourds_df['Adj Close']
fourds_volume = fourds_df['Volume']

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(fourds_time, fourds_adj_close, color='blue', label="Closing price")

# Rolling 10-day average / STD
def get_rolling_mean(values, window):
    return values.rolling(center=False, window=10).mean()
def get_rolling_std(values, window):
    return values.rolling(center=False, window=10).std()

# Bollinger bands
def get_bollinger_bands(rollingMean, rollingSTDEV):
    # Calculate upper and lower bollinger bands
    upper_band = rollingMean + rollingSTDEV * 2
    lower_band = rollingMean - rollingSTDEV * 2
    return upper_band, lower_band

def plot_data(fourds_df, title="Stock Prices"):
    # Add labels
    ax = fourds_df.plot(title=title, fontdict = font_1)
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    #plt.show()
    
    # Calculate daily returns
    daily_returns = fourds_adj_close
    plot_data(daily_returns, title = "Daily Returns")

    # Generate Bollinger Bands window=10 means 10-day moving avarage
    # Using get_rolling_mean to retrieve standard moving average, not exponential
    rolling_mean_MSFT = get_rolling_mean(fourds_df['Adj Close'], window=10)

     # Generate rolling standard deviation (10-day)
    rolling_STDEV_MSFT = get_rolling_std(four_df['Adj Close'], window=10)

    # Generate upper and lower bands
    upper_band, lower_band = get_bollinger_bands(rolling_mean_MSFT, rolling_STDEV_MSFT)

    # plot MSFT values, rolling mean and Bollinger Bands
    ax = fourds_df['Adj Close'].plot(title="Bollinger Bands", label='MSFT')
    rolling_mean_MSFT.plot(label='Rolling mean', ax=ax)
    upper_band.plot(label='upper band', ax=ax)
    lower_band.plot(label='lower band', ax=ax)

    # Add labels 
    ax.legend(loc='bottom left')
    ax.set_xlabel("Date")
    ax.set_ylabel("Price")
    plt.show()


#plt.title("4DS price performance, 1 May 2020 - 23 February 2022", fontdict = font_1)
#plt.xlabel("Date", fontdict = font_2)
#plt.ylabel("Price", fontdict = font_2)
#plt.legend()

# Aesthetics

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

#smooth = fourds_df['Adj Close'].rolling(window=10, label="Rolling 10-day average").mean()
#smooth.plot()

# Save and show
# plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/vanda-and-young-finalists-2021/Images/publishers.png", dpi=300)
#plt.show()

# %%
# plt.figure(figsize=(15,5))
# plt.bar(publishers, number_of_songs, color='blue', alpha=0.6, align="center")
# # plt.xticks(x, x, rotation=45)

# # Font families

# font_1 = {'family':'helvetica','color':'black','size':16}
# font_2 = {'family':'helvetica','color':'black','size':12}

# plt.title("Distribution of publishers for 2021 finalists",
#          fontdict = font_1)

# # Plot
# plt.xlabel("Publisher", fontdict = font_2)
# plt.ylabel("Number of songs", fontdict = font_2)

# # Aesthetics

# sns.set_context("paper")
# plt.gca().spines['top'].set_visible(False)
# plt.gca().spines['right'].set_visible(False)

# plt.tight_layout()
# #plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/vanda-and-young-finalists-2021/Images/publishers.png", 
#             dpi=300)
# plt.show()
