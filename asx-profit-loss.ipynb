# %%
# Import dependencies and setup
import matplotlib.pyplot as plt
import matplotlib as matplotlib
import pandas as pd
import datetime as dt
import matplotlib.dates as mdates

# %%
# Read .csv for each stock and store as DataFrame

# 4DS
fourds_file_path = "Resources/4DS.csv"
fourds_df = pd.read_csv(fourds_file_path)
fourds_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
fourds_df['TP'] = (fourds_df['Close'] + fourds_df['Low'] + fourds_df['High'])/3
fourds_df['std'] = fourds_df['TP'].rolling(20).std(ddof=0)
fourds_df['MA-TP'] = fourds_df['TP'].rolling(20).mean()
fourds_df['BOLU'] = fourds_df['MA-TP'] + 2*fourds_df['std']
fourds_df['BOLD'] = fourds_df['MA-TP'] - 2*fourds_df['std']
fourds_df = fourds_df.dropna()
fourds_df
# Out:
#         Date   Open   High    Low  Close  Adj Close   Volume        TP  \
# 19   28/5/20  0.051  0.054  0.050  0.051      0.051  5022669  0.051667
# 20   29/5/20  0.052  0.052  0.051  0.051      0.051   691570  0.051333
# 21    1/6/20  0.051  0.051  0.050  0.051      0.051   578105  0.050667
# 22    2/6/20  0.053  0.053  0.052  0.052      0.052  1247554  0.052333
# 23    3/6/20  0.053  0.054  0.052  0.054      0.054  1238216  0.053333
# ..       ...    ...    ...    ...    ...        ...      ...       ...
# 457  17/2/22  0.077  0.077  0.072  0.073      0.073  7551171  0.074000
# 458  18/2/22  0.072  0.072  0.069  0.070      0.070  9919401  0.070333
# 459  21/2/22  0.071  0.073  0.065  0.066      0.066  8155230  0.068000
# 460  22/2/22  0.065  0.067  0.062  0.064      0.064  8017361  0.064333
# 461  23/2/22  0.062  0.066  0.060  0.064      0.064  7882934  0.063333
#
#           std     MA-TP      BOLU      BOLD
# 19   0.002417  0.049417  0.054251  0.044582
# ...

# %%
# AFTP
aftp_file_path = "Resources/AFTP.csv"
aftp_df = pd.read_csv(aftp_file_path)
aftp_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
aftp_df['TP'] = (aftp_df['Close'] + aftp_df['Low'] + aftp_df['High'])/3
aftp_df['std'] = aftp_df['TP'].rolling(20).std(ddof=0)
aftp_df['MA-TP'] = aftp_df['TP'].rolling(20).mean()
aftp_df['BOLU'] = aftp_df['MA-TP'] + 2*aftp_df['std']
aftp_df['BOLD'] = aftp_df['MA-TP'] - 2*aftp_df['std']
aftp_df = aftp_df.dropna()
aftp_df
# Out:
#         Date       Open       High        Low      Close  Adj Close  Volume  \
# 19   29/5/20  31.230000  31.670000  31.230000  31.670000  31.670000    4700
# 20    1/6/20  32.750000  32.750000  32.005001  32.500000  32.500000    1900
# 21    2/6/20  32.750000  34.459999  32.750000  34.455002  34.455002    2600
# 22    3/6/20  36.099998  36.779999  36.099998  36.275002  36.275002    1200
# 23    4/6/20  36.070000  36.070000  36.070000  36.070000  36.070000     500
# ..       ...        ...        ...        ...        ...        ...     ...
# 452  15/2/22  41.700001  41.700001  39.680000  40.580002  40.580002  131400
# 453  16/2/22  40.290001  40.570000  40.279999  40.349998  40.349998   14700
# 454  17/2/22  40.689999  40.689999  40.110001  40.470001  40.470001   72500
# 455  18/2/22  40.360001  40.660000  40.360001  40.509998  40.509998   17500
# 456  22/2/22  39.849998  41.060001  39.849998  40.820000  40.820000  115800
#
# ...

# %%
# BRN
brn_file_path = "Resources/BRN.csv"
brn_df = pd.read_csv(brn_file_path)
brn_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
brn_df['TP'] = (brn_df['Close'] + brn_df['Low'] + brn_df['High'])/3
brn_df['std'] = brn_df['TP'].rolling(20).std(ddof=0)
brn_df['MA-TP'] = brn_df['TP'].rolling(20).mean()
brn_df['BOLU'] = brn_df['MA-TP'] + 2*brn_df['std']
brn_df['BOLD'] = brn_df['MA-TP'] - 2*brn_df['std']
brn_df = brn_df.dropna()
brn_df
# Out:
#         Date   Open   High     Low  Close  Adj Close    Volume        TP  \
# 19   28/5/20  0.079  0.080  0.0710  0.071      0.071  21536841  0.074000
# 20   29/5/20  0.072  0.073  0.0670  0.071      0.071  11760852  0.070333
# 21    1/6/20  0.074  0.079  0.0730  0.077      0.077  10003545  0.076333
# 22    2/6/20  0.078  0.080  0.0750  0.076      0.076   6316812  0.077000
# 23    3/6/20  0.078  0.079  0.0760  0.076      0.076   4744593  0.077000
# ..       ...    ...    ...     ...    ...        ...       ...       ...
# 457  17/2/22  1.460  1.465  1.4075  1.420      1.420  10384080  1.430833
# 458  18/2/22  1.380  1.450  1.3550  1.405      1.405  16292378  1.403333
# 459  21/2/22  1.390  1.395  1.2700  1.295      1.295  24413919  1.320000
# 460  22/2/22  1.250  1.295  1.1650  1.195      1.195  37743853  1.218333
# 461  23/2/22  1.170  1.275  1.1650  1.250      1.250  21302007  1.230000
#
#           std     MA-TP      BOLU      BOLD
# 19   0.008888  0.056992  0.074768  0.039216
# ...

# %%
# DW8
dw8_file_path = "Resources/DW8.csv"
dw8_df = pd.read_csv(dw8_file_path)
dw8_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
dw8_df['TP'] = (dw8_df['Close'] + dw8_df['Low'] + dw8_df['High'])/3
dw8_df['std'] = dw8_df['TP'].rolling(20).std(ddof=0)
dw8_df['MA-TP'] = dw8_df['TP'].rolling(20).mean()
dw8_df['BOLU'] = dw8_df['MA-TP'] + 2*dw8_df['std']
dw8_df['BOLD'] = dw8_df['MA-TP'] - 2*dw8_df['std']
dw8_df = dw8_df.dropna()
dw8_df
# Out:
#         Date   Open    High    Low   Close  Adj Close   Volume        TP  \
# 19   28/5/20  0.006  0.0060  0.006  0.0060     0.0060   165000  0.006000
# 20   29/5/20  0.006  0.0065  0.006  0.0065     0.0065   351200  0.006333
# 21    1/6/20  0.006  0.0065  0.006  0.0065     0.0065   948591  0.006333
# 22    2/6/20  0.006  0.0070  0.006  0.0060     0.0060   300046  0.006333
# 23    3/6/20  0.006  0.0070  0.006  0.0070     0.0070  5480222  0.006667
# ..       ...    ...     ...    ...     ...        ...      ...       ...
# 457  17/2/22  0.039  0.0410  0.039  0.0400     0.0400  3976783  0.040000
# 458  18/2/22  0.039  0.0410  0.039  0.0390     0.0390  6350267  0.039667
# 459  21/2/22  0.039  0.0390  0.038  0.0390     0.0390  3631123  0.038667
# 460  22/2/22  0.040  0.0400  0.037  0.0380     0.0380  3763997  0.038333
# 461  23/2/22  0.036  0.0380  0.036  0.0380     0.0380  3449501  0.037333
#
#           std     MA-TP      BOLU      BOLD
# 19   0.000415  0.006167  0.006997  0.005337
# ...

# %%
# IMU
imu_file_path = "Resources/IMU.csv"
imu_df = pd.read_csv(imu_file_path)
imu_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
imu_df['TP'] = (imu_df['Close'] + imu_df['Low'] + imu_df['High'])/3
imu_df['std'] = imu_df['TP'].rolling(20).std(ddof=0)
imu_df['MA-TP'] = imu_df['TP'].rolling(20).mean()
imu_df['BOLU'] = imu_df['MA-TP'] + 2*imu_df['std']
imu_df['BOLD'] = imu_df['MA-TP'] - 2*imu_df['std']
imu_df = imu_df.dropna()
imu_df
# Out:
#         Date   Open    High    Low  Close  Adj Close    Volume        TP  \
# 19   28/5/20  0.033  0.0350  0.032  0.034      0.034  20178061  0.033667
# 20   29/5/20  0.034  0.0350  0.034  0.034      0.034  11521262  0.034333
# 21    1/6/20  0.034  0.0350  0.033  0.033      0.033   7654312  0.033667
# 22    2/6/20  0.034  0.0355  0.034  0.034      0.034  13340359  0.034500
# 23    3/6/20  0.034  0.0350  0.034  0.034      0.034  10051693  0.034333
# ..       ...    ...     ...    ...    ...        ...       ...       ...
# 457  17/2/22  0.310  0.3150  0.300  0.310      0.310  38502826  0.308333
# 458  18/2/22  0.295  0.3100  0.295  0.300      0.300  15416970  0.301667
# 459  21/2/22  0.300  0.3000  0.280  0.280      0.280  20212704  0.286667
# 460  22/2/22  0.280  0.2800  0.250  0.255      0.255  58304658  0.261667
# 461  23/2/22  0.250  0.2700  0.245  0.260      0.260  35872403  0.258333
#
#           std     MA-TP      BOLU      BOLD
# 19   0.002401  0.030633  0.035434  0.025832
# ...

# %%
# NVA
nva_file_path = "Resources/NVA.csv"
nva_df = pd.read_csv(nva_file_path)
nva_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
nva_df['TP'] = (nva_df['Close'] + nva_df['Low'] + nva_df['High'])/3
nva_df['std'] = nva_df['TP'].rolling(20).std(ddof=0)
nva_df['MA-TP'] = nva_df['TP'].rolling(20).mean()
nva_df['BOLU'] = nva_df['MA-TP'] + 2*nva_df['std']
nva_df['BOLD'] = nva_df['MA-TP'] - 2*nva_df['std']
nva_df = nva_df.dropna()
nva_df
# Out:
#         Date   Open   High   Low  Close  Adj Close   Volume        TP  \
# 19   28/5/20  0.510  0.590  0.51  0.570      0.570  1671803  0.556667
# 20   29/5/20  0.570  0.580  0.55  0.570      0.570   826810  0.566667
# 21    1/6/20  0.580  0.660  0.58  0.660      0.660  1755866  0.633333
# 22    2/6/20  0.660  0.670  0.61  0.630      0.630  1021790  0.636667
# 23    3/6/20  0.640  0.660  0.62  0.620      0.620   645066  0.633333
# ..       ...    ...    ...   ...    ...        ...      ...       ...
# 457  17/2/22  0.915  0.915  0.87  0.900      0.900   222456  0.895000
# 458  18/2/22  0.915  0.945  0.90  0.930      0.930   149362  0.925000
# 459  21/2/22  0.960  0.990  0.90  0.905      0.905   327561  0.931667
# 460  22/2/22  0.910  0.915  0.85  0.870      0.870   321093  0.878333
# 461  23/2/22  0.850  0.895  0.84  0.885      0.885    98785  0.873333
#
#           std     MA-TP      BOLU      BOLD
# 19   0.021823  0.496000  0.539645  0.452355
# ...

# %%
# RAC
rac_file_path = "Resources/RAC.csv"
rac_df = pd.read_csv(rac_file_path)
rac_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
rac_df['TP'] = (rac_df['Close'] + rac_df['Low'] + rac_df['High'])/3
rac_df['std'] = rac_df['TP'].rolling(20).std(ddof=0)
rac_df['MA-TP'] = rac_df['TP'].rolling(20).mean()
rac_df['BOLU'] = rac_df['MA-TP'] + 2*rac_df['std']
rac_df['BOLD'] = rac_df['MA-TP'] - 2*rac_df['std']
rac_df = rac_df.dropna()
rac_df
# Out:
#         Date   Open   High    Low  Close  Adj Close  Volume        TP  \
# 19   28/5/20  0.310  0.320  0.300  0.315      0.315  177273  0.311667
# 20   29/5/20  0.320  0.325  0.310  0.325      0.325   97121  0.320000
# 21    1/6/20  0.330  0.335  0.320  0.320      0.320   76581  0.325000
# 22    2/6/20  0.320  0.320  0.315  0.315      0.315   14756  0.316667
# 23    3/6/20  0.345  0.350  0.310  0.325      0.325  272831  0.328333
# ..       ...    ...    ...    ...    ...        ...     ...       ...
# 457  17/2/22  2.940  2.940  2.840  2.860      2.860  150065  2.880000
# 458  18/2/22  2.810  2.850  2.800  2.820      2.820  160182  2.823333
# 459  21/2/22  2.810  2.830  2.740  2.800      2.800  507481  2.790000
# 460  22/2/22  2.800  2.800  2.730  2.800      2.800  372018  2.776667
# 461  23/2/22  2.790  2.900  2.790  2.890      2.890  146053  2.860000
#
#           std     MA-TP      BOLU      BOLD
# 19   0.026060  0.339833  0.391954  0.287713
# ...

# %%
# TNR
tnr_file_path = "Resources/TNR.csv"
tnr_df = pd.read_csv(tnr_file_path)
tnr_df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Define and add 'TP', 'STD', 'MA-TP', 'BOLU' and 'BOLD' columns
tnr_df['TP'] = (tnr_df['Close'] + tnr_df['Low'] + tnr_df['High'])/3
tnr_df['std'] = tnr_df['TP'].rolling(20).std(ddof=0)
tnr_df['MA-TP'] = tnr_df['TP'].rolling(20).mean()
tnr_df['BOLU'] = tnr_df['MA-TP'] + 2*tnr_df['std']
tnr_df['BOLD'] = tnr_df['MA-TP'] - 2*tnr_df['std']
tnr_df = tnr_df.dropna()
tnr_df
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume  \
# 19   28/5/20  0.028799  0.028799  0.027839  0.027839   0.027839   2006905
# 20   29/5/20  0.028799  0.029759  0.025919  0.026879   0.026879   2840694
# 21    1/6/20  0.028799  0.039359  0.028799  0.033599   0.033599  29411935
# 22    2/6/20  0.035519  0.037439  0.032639  0.033599   0.033599  10424993
# 23    3/6/20  0.035519  0.036479  0.034559  0.036479   0.036479   6023946
# ..       ...       ...       ...       ...       ...        ...       ...
# 457  17/2/22  0.028000  0.029000  0.028000  0.028000   0.028000    838159
# 458  18/2/22  0.029000  0.029000  0.028500  0.029000   0.029000   2848130
# 459  21/2/22  0.029000  0.029000  0.027000  0.028000   0.028000   3016825
# 460  22/2/22  0.028000  0.028000  0.026000  0.026000   0.026000   5805127
# 461  23/2/22  0.026000  0.027000  0.026000  0.027000   0.027000   1875187
#
#            TP       std     MA-TP      BOLU      BOLD
# ...

# %%
# Plot each ticker as seperate line graphs

# 4DS

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting

plt.figure(figsize=(15,5))
plt.plot(fourds_df["Date"], fourds_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(fourds_df["Date"], fourds_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(fourds_df["Date"], fourds_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(fourds_df["Date"], fourds_df["BOLD"], color='orange', linewidth=1, label="BOLD")

d = fourds_df['Date'].values
plt.fill_between(d, fourds_df["BOLU"], fourds_df["BOLD"],
                where=fourds_df["BOLU"] >= fourds_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("4DS price performance, 25 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((fourds_df['Date'])[::20], rotation=35)

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/4DS.png", dpi=300)
plt.show()

# %%
# AFTP

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(aftp_df["Date"], aftp_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(aftp_df["Date"], aftp_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(aftp_df["Date"], aftp_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(aftp_df["Date"], aftp_df["BOLD"], color='orange', linewidth=1, label="BOLD")
d = aftp_df['Date'].values
plt.fill_between(d, aftp_df["BOLU"], aftp_df["BOLD"],
                where=aftp_df["BOLU"] >= aftp_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("AFTP price performance, 29 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((aftp_df['Date'])[::20], rotation=35)

# Aesthetics

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/AFTP.png", dpi=300)
plt.show()

# %%
# BRN

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(brn_df["Date"], brn_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(brn_df["Date"], brn_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(brn_df["Date"], brn_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(brn_df["Date"], brn_df["BOLD"], color='orange', linewidth=1, label="BOLD")
d = brn_df['Date'].values
plt.fill_between(d, brn_df["BOLU"], brn_df["BOLD"],
                where=brn_df["BOLU"] >= brn_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("BRN price performance, 28 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((brn_df['Date'])[::20], rotation=35)

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/BRN.png", dpi=300)
plt.show()

# %%
# DW8

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(dw8_df["Date"], dw8_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(dw8_df["Date"], dw8_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(dw8_df["Date"], dw8_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(dw8_df["Date"], dw8_df["BOLD"], color='orange', linewidth=1, label="BOLD")
d = dw8_df['Date'].values
plt.fill_between(d, dw8_df["BOLU"], dw8_df["BOLD"],
                where=dw8_df["BOLU"] >= dw8_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("DW8 price performance, 28 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((dw8_df['Date'])[::20], rotation=35)

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/DW8.png", dpi=300)
plt.show()

# %%
# IMU

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(imu_df["Date"], imu_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(imu_df["Date"], imu_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(imu_df["Date"], imu_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(imu_df["Date"], imu_df["BOLD"], color='orange', linewidth=1, label="BOLD")
d = imu_df['Date'].values
plt.fill_between(d, imu_df["BOLU"], imu_df["BOLD"],
                where=imu_df["BOLU"] >= imu_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("IMU price performance, 28 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((imu_df['Date'])[::20], rotation=35)

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/IMU.png", dpi=300)
plt.show()

# %%
# NVA

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(nva_df["Date"], nva_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(nva_df["Date"], nva_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(nva_df["Date"], nva_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(nva_df["Date"], nva_df["BOLD"], color='orange', linewidth=1, label="BOLD")
d = nva_df['Date'].values
plt.fill_between(d, nva_df["BOLU"], nva_df["BOLD"],
                where=nva_df["BOLU"] >= nva_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("NVA price performance, 28 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((nva_df['Date'])[::20], rotation=35)

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/NVA.png", dpi=300)
plt.show()

# %%
# RAC

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(rac_df["Date"], rac_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(rac_df["Date"], rac_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(rac_df["Date"], rac_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(rac_df["Date"], rac_df["BOLD"], color='orange', linewidth=1, label="BOLD")
d = rac_df['Date'].values
plt.fill_between(d, rac_df["BOLU"], rac_df["BOLD"],
                where=rac_df["BOLU"] >= rac_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("RAC price performance, 28 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((rac_df['Date'])[::20], rotation=35)

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/RAC.png", dpi=300)
plt.show()

# %%
# TNR

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plotting
plt.figure(figsize=(15,5))
plt.plot(tnr_df["Date"], tnr_df["Adj Close"], color='blue', linewidth=2, label="Closing price")
plt.plot(tnr_df["Date"], tnr_df["MA-TP"], color='red', linewidth=2, label="Rolling 20-day average")
plt.plot(tnr_df["Date"], tnr_df["BOLU"], color='green', linewidth=1, label="BOLU")
plt.plot(tnr_df["Date"], tnr_df["BOLD"], color='orange', linewidth=1, label="BOLD")
d = tnr_df['Date'].values
plt.fill_between(d, tnr_df["BOLU"], tnr_df["BOLD"],
                where=tnr_df["BOLU"] >= tnr_df["BOLD"],
                facecolor='green', alpha=0.1, interpolate=True)

plt.title("TNR price performance, 28 May 2020 — 21 February 2022", fontdict = font_1)
plt.xlabel("Date", fontdict = font_2)
plt.ylabel("Price (AUD)", fontdict = font_2)
plt.legend()

plt.xticks((tnr_df['Date'])[::20], rotation=35)

# Aesthetics

matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/asx-profit-loss/Images/TNR.png", dpi=300)
plt.show()
